# %% [markdown]
# # Opencv
# OpenCV is one of the most popular computer vision libraries. If you want to start your journey in the field of computer vision,
# then a thorough understanding of the concepts of OpenCV is of paramount importance.
#
# This article will cover the following topics:
# 1.Reading an image
# 2.Resizing the Image
# 3.Blurred Image
# 4.edges the image
# 5.Airthmetic operation

# %%
#import libraries
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
# Python code to read image
img1 = cv2.imread(r"C:\Users\tharaniv\Downloads\fantasy-3077928_1280.jpg")

plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title("Over the Clouds - original color image")
# Out:
# Text(0.5, 1.0, 'Over the Clouds - original color image')

# %%
# Using 0 to read image in grayscale mode
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap = 'gray')
plt.title("Over the Clouds - gray")
# Out:
# Text(0.5, 1.0, 'Over the Clouds - gray')

# %%
# resize() function takes 2 parameters, 
# the image and the dimensions
image = cv2.imread(r"C:\Users\tharaniv\Downloads\fantasy-3077928_1280.jpg")

# Loading the image
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1000, 900))
 
Titles =["Original", "Half", "Bigger"]
images =[image, half, bigger]
count = 3
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
    plt.show()

# %%
# Display the blurred image
Gaussian = cv2.GaussianBlur(img1, (7, 7), 0)
cv2.imshow('Gaussian Blurring', Gaussian)
cv2.waitKey(0)

plt.imshow(Gaussian)
plt.show()

# %%
# Detect edges in the image using Canny edge detection
edges = cv2.Canny(gray, 50, 500)
# Display the edges
cv2.imshow('Edges', edges)

plt.imshow(edges)
plt.show()

# %%
img2 = cv2.imread(r'C:\Users\tharaniv\Downloads\maxresdefault.jpg')

plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title("Over the Clouds - original color image")
# Out:
# Text(0.5, 1.0, 'Over the Clouds - original color image')

# %%
# arithmetic operation of
# addition of two images
 
img1 = cv2.imread(r'C:\Users\tharaniv\Downloads\fantasy-3077928_1280.jpg') 
img2 = cv2.imread(r'C:\Users\tharaniv\Downloads\maxresdefault.jpg')

# cv2.addWeighted is applied over the
# image inputs with applied parameters
weightedSum = cv2.addWeighted(img1, 0.5, img2, 0.4, 0)
  
# the window showing output image
# with the weighted sum 
cv2.imshow('Weighted Image', weightedSum)
  
# De-allocate any associated memory usage  
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows() 
    
plt.imshow(weightedSum)
plt.show()

# %%
# path to input images are specified and  
# images are loaded with imread command 
img1 = cv2.imread(r'C:\Users\tharaniv\Downloads\hovering-hummer-jean-noren.jpg') 
img2 = cv2.imread(r'C:\Users\tharaniv\Downloads\wings-dan-pyle.jpg')
  
# cv2.subtract is applied over the
# image inputs with applied parameters
sub = cv2.subtract(img1, img2)
  
# the window showing output image
# with the subtracted image 
cv2.imshow('Subtracted Image', sub)
  
# De-allocate any associated memory usage  
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows() 
    
plt.imshow(sub)
plt.show()
